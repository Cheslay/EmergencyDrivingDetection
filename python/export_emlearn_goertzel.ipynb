# %%
import joblib
import emlearn

bundle = joblib.load("rf10_goertzel_frozen.joblib")
rf = bundle["model"]

c_model = emlearn.convert(
    rf,
    method="inline",
    dtype="float"
)

c_model.save(file="rf10_goertzel_model.h")
print("✔ C-model genereret")
# Out:
# ✔ C-model genereret
