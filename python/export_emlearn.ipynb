# %%
import emlearn
import joblib

bundle = joblib.load("rf10_frozen.joblib")
rf = bundle["model"]

c_model = emlearn.convert(
    rf,
    method="inline",
    dtype="float"
)

with open("rf_model.h", "w") as f:
    f.write(c_model.save(name="rf_model"))

print("✔ rf_model.h genereret")
# Out:
# ✔ rf_model.h genereret
